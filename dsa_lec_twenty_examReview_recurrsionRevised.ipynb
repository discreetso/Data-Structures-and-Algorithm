# %%
# 1. Look carefully at the following code of the quick sort and fix the bugs

import random 

def qsort(l, fst, lst):
    if fst >= lst: return

    i, j = fst, lst
    pivot = l[random.randint(fst, lst)]

    while i <= j:
        while l[i] < pivot: i -= 1
        while l[j] < pivot: j += 1
        if i <= j:
            l[i], l[j] = l[j], l[i]
            i, j = j+1, i-1
            
            qsort(l, fst, j)

# %%
# solution to the first problem
# BUGS
# bug1: i goes forward and j goes backward
# bug2: we do swap of values, not the swap of indices
# bug3: quick sort have two recurrsion calls, second recurrsion call is missing

import random

def qsort(l, fst, lst):
    if fst >= lst: return 
        
    i, j = fst, lst
    pivot = l[random.randint(fst, lst)]
    
    while i <= j:
        while l[i] < pivot: i += 1
        while l[j] > pivot: j -= 1
        
        if i <= j:
            l[i], l[j] = l[j], l[i]
            i, j = i+1, j-1

    qsort(l, fst, j)
    qsort(l, i, lst)

# %%
# 2. for the following tree, write the order of nodes visited, if we do (a) pre-order, (b) in-order and (c) post-order
# solution on the notebook
